# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Александр, привет!</b>
#
# Меня зовут Евгений Дащенко, и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Критическая ошибка: ❌</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Хорошо, но можно и лучше: ❗️</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Все отлично: ✅</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# # Исследование успешности игр

# %% [markdown]
# Данный проект выполнен для оценки компании "Стримчик" на 2017 год. В том числе, поставлены следующие задачи:
# - Определить сколько игр выпускалось в разные годы.
# - Как изменялись продажи по платформам с годами?
# - Какие платформы лидируют в продажах за последние года?
# - Как влияют на продажи отзывы критиков и пользователей?
# - Какие жанры самые прибыльные?
# - Составить портрет пользователя из разных регионов.
# - Определить как различаются между собой пользовательские рейтинги платформ Xbox One и PC.
# - Определить как различаются между собой пользовательские рейтинги Action и Sports.
#
# В качестве исходных данных был прислан датафрейм с необходимой информацией по продажам, типам игр и т.д. начиная с 1980-х годов до 2016.
# Для решения поставленной задачи необходимо будет ознакомиться с данными, провести их предобработку (если потребуется) и провести исследовательский и статистический анализ.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться в концепции / деталях работы. Можно также привести краткий план проведения самой работы и описание используемых столбцов.
#
# </div>

# %% [markdown]
# ## Знакомство с исходными данными

# %% [markdown]
# Импортируем необходимые для работы библиотеки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import statsmodels.api as sm
import scipy as st

# %% [markdown]
# Запишем исходный датафрейм в переменную, с которой будем работать.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# <s>Здесь у нас некорректные пути, ниже поправил, чтобы запустить.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Спасибо. Оставил твой вариант только</div>

# %%
data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# Посмотрим первые 10 строчек исходного датафрейма. Посмотрим info() и describe()

# %%
data.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный и удобный способ визуализировать распределения по всем столбцам сразу 👍
# </div>

# %% [markdown]
# В столбцах `Critic_score`, `User_score`, `Raiting`, `Years_of_realese` имеется множество незаполненных данных. Наименование столбцов некорректно и необходимо привести названия к единому нижнем регистру. Так как пропущенные данные в столбцах `Critic_Score`, `User_Score` нам неизвестны и невозможно их логичено заполнить, а также пропуски не влияют на наше исследование оставим их в том виде, в котором они и есть. Пропуски в столбце `Years_of_realese` незначительны и можно их отбросить.

# %% [markdown]
# Посмотрим уникальные значания столбца `Rating`.

# %%
data.Rating.unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Так как рейтинг K-A это устаревшее наименование рейтинга Е, то необходимо будет сделать замену.

# %% [markdown]
# Посмотрим уникальные значения столбца `User_Score`.

# %%
data.User_Score.unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# В столбце имеются значения `tbd`. По всей видимости, это расшифровывается как to be determined - будет определено. Необходимо заменить данные на `NaN` и привести значения в столбце к типу `float`, чтобы они не влияли на дальнейшее исследование.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Датафрейм представляет собой таблицу со столбцами:
# `Name` — название игры;
# `Platform` — платформа;
# `Year_of_Release` — год выпуска;
# `Genre` — жанр игры;
# `NA_sales` — продажи в Северной Америке (миллионы проданных копий);
# `EU_sales` — продажи в Европе (миллионы проданных копий);
# `JP_sales` — продажи в Японии (миллионы проданных копий);
# `Other_sales` — продажи в других странах (миллионы проданных копий);
# `Critic_Score` — оценка критиков (максимум 100);
# `User_Score` — оценка пользователей (максимум 10);
# `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# При знакомстве с исходными данными были определены основные проблемы в виде пропущенных данных, неверные названия столбцов и неверный тип данных. Необходимо провести предобработку данных для решения этих проблем.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### 1. Приведем названия столбцов к нижнем регистру

# %%
data.columns = data.columns.str.lower()
#приведем наименования столбцов к нижнему регистру

data.head()
#посмотрим, что все впорядке
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный способ заменить регистр в наших данных 👍
# </div>

# %%
for item in ['name', 'platform', 'genre', 'rating']:
    data[item] = data[item].str.lower()
#приведем значения в столбцах к нижнему регистру

data.head()
#посмотрим, что все впорядке
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii           2006.0        sports     41.36
# 1         super mario bros.      nes           1985.0      platform     29.08
# 2            mario kart wii      wii           2008.0        racing     15.68
# 3         wii sports resort      wii           2009.0        sports     15.61
# 4  pokemon red/pokemon blue       gb           1996.0  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      e
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      e
# 3     10.93      3.28         2.95          80.0          8      e
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# <s>Однотипные расчеты мы можем всегда автоматизировать с помощью цикла `for` и тем самым оптимизировать код внутри проекта.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Согласен. Исправил на цикл</div>

# %% [markdown]
# ### 2. Заменим значания `K-A` в столбце `rating` на `e`.

# %%
data.loc[data.rating == 'k-a', 'rating'] = 'e'

# %% [markdown]
# ### 3. Отсортируем данные по году выпуска в порядке убывания.

# %%
data = data.sort_values(by='year_of_release')

# %% [markdown]
# ### 4. Заменим значения `tbd` в столбце `user_score` на NaN и приведем столбце к типу `float`.

# %%
data.loc[data.user_score == 'tbd', 'user_score'] =  np.nan
#заменим значания на NaN

data.user_score = data.user_score.astype('float')
#приведем к типу float

data.info()
#посмотрим, что все впорядке
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16715 entries, 1764 to 16522
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 5. Удалим строки с пропущенными данными из столбца `year_of_release` и изменим тип данных на `int`.

# %%
data = data.dropna(subset=['year_of_release'])
#удалим строки с пропусками

data = data.reset_index(drop=True)
#обновим индексы

data.year_of_release = data.year_of_release.astype('int')
#приведем данные в столбце к типу int

data.info()
#посмотрим, что все впорядке
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16446 entries, 0 to 16445
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16446 non-null  object
#  2   year_of_release  16446 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16446 non-null  float64
#  5   eu_sales         16446 non-null  float64
#  6   jp_sales         16446 non-null  float64
#  7   other_sales      16446 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# <s>Здесь все таки пошло что-то не так. Посмотри пожалуйста в чем дело здесь на сервере.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Исправил ошибку здесь и ниже. Вроде все работает теперь</div>

# %% [markdown]
# ### 6. Удалим пропущенные значения в столбце `name`.

# %%
data = data.dropna(subset=['name'])
#удалим значания

data = data.reset_index(drop=True)
#обновим индексы

data.info()
#посмотрим, что все впорядке
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### 7. Добавим столбец с суммарными продажами для каждой игры в датафрейм.

# %%
data['sum_of_sales'] = data[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
#добавим новым столбец с данными

data.head()
#посмотрим, что все впорядке
# Out:
#               name platform  year_of_release    genre  na_sales  eu_sales  \
# 0          kaboom!     2600             1980     misc      1.07      0.07
# 1  missile command     2600             1980  shooter      2.56      0.17
# 2         defender     2600             1980     misc      0.99      0.05
# 3           bridge     2600             1980     misc      0.25      0.02
# 4         checkers     2600             1980     misc      0.22      0.01
#
#    jp_sales  other_sales  critic_score  user_score rating  sum_of_sales
# 0       0.0         0.01           NaN         NaN    NaN          1.15
# 1       0.0         0.03           NaN         NaN    NaN          2.76
# 2       0.0         0.01           NaN         NaN    NaN          1.05
# 3       0.0         0.00           NaN         NaN    NaN          0.27
# 4       0.0         0.00           NaN         NaN    NaN          0.23

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати мы можем применить метод `sum(axis=1)` к суммируемым столбцам.
#
# `df[['col1', 'col2', 'col3']].sum(axis=1)`
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Здорово! Попробовал так сделать</div>

# %% [markdown]
# ### 8. Вывод

# %% [markdown]
# В части предобработки данных были скорректированны данные внутри датафрейма, удалены повторяющиеся данные и строки с отсутствующими данными.
# Так же в датафрейм был добавлен новый столбец с суммарными продажами по играм.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### 1. Изменение количества игр по годам выпуска.

# %%
(
    data
    .pivot_table(index='year_of_release', values='name', aggfunc='count') 
    #отфильтруем данные, посчитаем количество игр по названию
    .plot(grid=True, sharex=False, figsize=(12,5)) 
    #нарисуем график
)

plt.title('Количество выпускаемых игр по годам')
plt.xlabel('Year', color='gray')
plt.ylabel('Quntity', color='gray')
plt.legend(['Количество игр'], loc=2)
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# Как видно из графика, до 1990 года количество выпускаемых игр было очень малым из-за того, что компьютерная техника была несильно развита и в основном использовалась для промышленных применений. Далее количество игр начиная с 1990 годов возрастало до ~2007 года и затем наблюдается спад. Тенденция графика направлена вниз. Возможно, стоит ожидать продолжение спада в будущем.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, когда график и его оси подписаны 😊👍
#
# Так быстрее понять о чем идёт речь на самом графике.
#
# </div>

# %% [markdown]
# ### 2. Сравнение продаж по платформам.

# %%
(
    data
    .pivot_table(index='platform', values='sum_of_sales', aggfunc='median') #отфильтруем данные, посчитаем продажи по платформам
    .sort_values(by='sum_of_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по платформам')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Суммарные продажи'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# Как видно из графика, самые продаваемые игры выпускаются на платформах `NES`, `GB`, `2600`, `SNES` и `X360`.
# Построим график по данным топ-5 самых успешных платформ по годам

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, что график увеличен 👍, так гораздо легче изучать эту информацию.
#
# </div>

# %%
top_sales_platform_name = ['nes','gb','2600','snes','x360'] #создадим переменную с топ-5 платформ

#создадим датафрейм, где будут продажи только по топ-5 платформ
top_sales_platform_df = (
    data
    .loc[data.platform.isin(top_sales_platform_name) == True, ['platform', 'year_of_release', 'sum_of_sales']]
    #отсортируем необходимые столбцы с необходимыми данными из всего датафрейма
    .pivot_table(index=['platform', 'year_of_release'], values='sum_of_sales', aggfunc='median') 
    #отфильтруем данные и посчитаем суммарно продажи по году и платформе
    .pivot_table(index='year_of_release', values='sum_of_sales', columns='platform') 
    #развернем таблицу
    .reset_index() 
    #обнулим индексы
)

#создадим подграфики
fig, axs = plt.subplots(len(top_sales_platform_name),
                        sharex='row',
                        sharey=True,
                        figsize=(15, 15))

#зададим общее оглавление таблицы
fig.suptitle('Продажи топ-5 платформ по годам') 

#создадим перменную для всех лет от 1985 до 2017 годов и заполним ее в цикле
labels_xticks = []
for i in range(33):
    labels_xticks.append(1985+i)

#построим графики для всех топ-5 платформ по суммам продаж
for i,ax in enumerate(axs):
    axs[i].plot(top_sales_platform_df['year_of_release'], top_sales_platform_df.iloc[:,i+1], 'o-')  
    axs[i].set_xlim((1985, 2017)) #настроим видимость (откинем лишнюю часть до 1995 года)
    axs[i].grid() #добавим сетку
    axs[i].set_ylabel('Продажи, млн.', color='gray') #добавим подписи по оси y
    axs[i].xaxis.set_major_locator(ticker.FixedLocator(labels_xticks)) #добавим подписи по оси х
    axs[i].title.set_text(top_sales_platform_df.columns[i+1]) #добавим подписи для каждого графика
    axs[i].set_xticklabels(labels_xticks, rotation=45) #повернем тики на 45 градусов

plt.subplots_adjust(hspace=0.5) #добавим промежуток между графиками
plt.show() #отобразим графики

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# <s>Обрати внимание, что график не совсем читабелен, потому что включает в себя много линий. Обычно используют 2-3 линии максимум на одном графике, чтобы повысить комфортность изучения графика.
#
# Рекомендовал бы посмотреть каждую платформу на отдельном графике или использовать метод `subplots` построив графики в 2 столбца например.
#
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Спасибо за подсказку. Решил поизучать subplots и попробовать все в цикле сделать. Вот что получилось. Может есть советы как их еще более информативнее и красивее сделать?</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Можно попробовать без `subplots`, визуализировать с помощью тепловой карты `heatmap`. Предварительно сделав таблицу с годами в столбцах.
#
#
# </div>

# %% [markdown]
# Посчитаем средний срок жизни платформ.

# %%
platform_years_of_life = data.pivot_table(index='platform', values='year_of_release', aggfunc=['max', 'min'])
#сделаем срез и сохраним в новую переменную
platform_years_of_life['life_in_years'] = platform_years_of_life['max'] - platform_years_of_life['min']
#добавим новый столбец, где посчитаем года жизни для каждой платформы
platform_years_of_life['life_in_years'].mean()
#высчитаем среднее среди всех платформ
# Out:
# 7.612903225806452

# %% [markdown]
# Как видно из графиков и расчета, платформы в среднем имеют прдолжительность жизни около 7.6 лет.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Согласен.
#
# В том числе мы могли посчитать срок жизни платформы – вычесть из максимальной даты минимальную по каждой платформе и затем усреднить получившиеся значения.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Проверил дополнительно тем методом, что ты предложил. Немного скорректировал вывод</div>

# %% [markdown]
# ### 3. Определение самых продаваемых платформ.

# %% [markdown]
# Для того, чтобы верно сформулировать прогноз на будущее возьмем срез данных с 2008 года по 2016.

# %%
data_last_years = data.loc[(data.year_of_release >= 2008)] #возьмем срез данных за 2008-2016 года

(
    data_last_years
    .pivot_table(index='platform', values='sum_of_sales', aggfunc='median') #отфильтруем данные, посчитаем продажи по платформам
    .sort_values(by='sum_of_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Средние продажи по платформам')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Средние продажи', color='gray')
plt.legend(['Среднее по суммарным продажам'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
data_last_years_platform_sales_sum_df = (
    data_last_years
    #возьмем датафрейм за 2008-2016 года
    .pivot_table(index=['platform', 'year_of_release'], values='sum_of_sales', aggfunc='median')
    #отфильтруем данные и посчитаем суммарно продажи по году и платформе
    .pivot_table(index='year_of_release', values='sum_of_sales', columns='platform')
    #развернем таблицу
    .reset_index()
    #обнулим индексы
)

#создадим подграфики
fig, axs = plt.subplots(int((len(data_last_years_platform_sales_sum_df.columns)-1)/2), 2,
                        sharex='row',
                        sharey=True,
                        figsize=(15, 35))

#зададим общее оглавление таблицы
fig.suptitle('Среднии продажи по платформам за 2008-2016 года') 

#перезапишем ранее созданую переменную для всех лет от 2008 до 2017 годов и заполним ее в цикле
labels_xticks = []
for i in range(10):
    labels_xticks.append(2007+i)

counter=0 #создадим счетчик
    
#построим графики для всех топ-5 платформ по суммам продаж
for i, ax in enumerate(axs):
    for j in range(2):
        counter += 1 #добавляем единицу к счетчику
        axs[i][j].plot(data_last_years_platform_sales_sum_df['year_of_release'],
                       data_last_years_platform_sales_sum_df.iloc[:,counter], 'o-') #нарисуем графики  
        axs[i][j].grid() #добавим сетку
        axs[i][j].set_ylabel('Продажи, млн.', color='gray') #добавим подписи по оси y
        axs[i][j].xaxis.set_major_locator(ticker.FixedLocator(labels_xticks)) #добавим подписи по оси х
        axs[i][j].title.set_text(data_last_years_platform_sales_sum_df.columns[counter]) #добавим подписи для каждого графика
        axs[i][j].set_xticklabels(labels_xticks, rotation=45) #повернем тики на 45 градусов

        
plt.subplots_adjust(hspace=0.3) #добавим промежуток между графиками
plt.show() #отобразим графики
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Обрати внимание, что наши действия повторяются с точки зрения построения графиков.
#
# Это говорит о том, что мы можем создать функцию, которая будет выполнять все действия за нас.
#
# Тем самым мы сможем оптимизировать свой код и проект целиком.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Тут тоже сделал разными графиками</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# 🔥🔥🔥
#
#
# </div>

# %% [markdown]
# По графику видно, что практически все платформы теряют популярность. В среднем за 2008-2016 года самыми популярными были `X360`, `PS3`, `WIIU` и `Xone`. По графикам видно, что на 2016 год рост показывают платформы `PS3` и `WII`, остальные имеют тенденцию к снижению. Исходя из этого можно сделать вывод, что самой прибыльной платформой будет `PS3`.

# %% [markdown]
# ### 4. Изучение диаграммы размаха для суммарных продаж в разбивке по платформам.

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .loc[(data_last_years.platform == 'ps4')| #возьмем данные только по самым продаваемым платформам
         (data_last_years.platform == 'xone')|
         (data_last_years.platform == '3ds')|
         (data_last_years.platform == 'pc')]       
    .boxplot(by='platform', column='sum_of_sales', figsize=(10,7), grid=True, showfliers=False) #построим график
)

plt.title('График размаха по самым продаваемым платформам за 2008-2016')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Сумма продаж', color='gray')
plt.show()
#зададим параметры оглавление, подписи по осям

# %% [markdown]
# Увидим, что данные в основном лежат в промежутке до единицы. По остальным параметрам данные имеют множественные выбросы.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный способ визуализировать разброс данных по каждой платформе 👍
#
# Кстати мы можем использовать параметр `showfliers=False`, чтобы убрать выбросы с графика.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Ого! Спасибо за подсказку)</div>

# %% [markdown]
# ### 5. Изучим как на продажи влияют отзывы критиков и отзывы пользователей.

# %%
(
    data_last_years
    .loc[data_last_years.platform == 'x360'][['critic_score', 'sum_of_sales']]
    .corr(method='spearman') #проверим корреляцию методом Спирмена для данных по платформе X360 за 2008-2016 года
)
# Out:
#               critic_score  sum_of_sales
# critic_score      1.000000      0.674324
# sum_of_sales      0.674324      1.000000

# %%
plt.scatter(
    data_last_years.loc[data_last_years.platform == 'x360'].critic_score,
    data_last_years.loc[data_last_years.platform == 'x360'].sum_of_sales
)
#построим диаграмму рассеяния

plt.title('Как влияют на продажи игр на X360 оценки критиков. 2008-2016')
plt.xlabel('Оценки критиков')
plt.ylabel('Сумма продаж')
plt.show()
#зададим параметры оглавление, подписи по осям

# %% [markdown]
# Посчитав корреляцию по отзывам критиков и продажам самой популярной платфоры `X360` можем увидеть, что корреляция есть.

# %%
(
    data_last_years
    .loc[data_last_years.platform == 'x360'][['user_score', 'sum_of_sales']]
    .corr(method='spearman') #проверим корреляцию методом Спирмена для данных по платформе PS4 за 2008-2016 года
)
# Out:
#               user_score  sum_of_sales
# user_score      1.000000      0.290679
# sum_of_sales    0.290679      1.000000

# %%
plt.scatter(
    data_last_years.loc[data_last_years.platform == 'x360'].user_score,
    data_last_years.loc[data_last_years.platform == 'x360'].sum_of_sales
)
#построим диаграмму рассеяния

plt.title('Как влияют на продажи игр на X360 оценки пользователей. 2008-2016')
plt.xlabel('Оценки пользователей')
plt.ylabel('Сумма продаж')
plt.show()
#зададим параметры оглавление, подписи по осям

# %% [markdown]
# Корреляция с оценками пользователей отсутствует.

# %% [markdown]
# Построим диаграммы рассеяния для других платформ из самых продаваемых и оценок критиков.

# %%
top_sales_platform_last_year = ['ps3','wiiu','xone']

for item in top_sales_platform_last_year:
    title = 'Как влияют на продажи игр на ' + item + ' оценки критиков. 2008-2016'
  
    plt.scatter(
        data_last_years.loc[data_last_years.platform == item].critic_score,
        data_last_years.loc[data_last_years.platform == item].sum_of_sales
    )
    #построим диаграмму рассеяния
    
    plt.title(title)
    plt.xlabel('Оценки критиков')
    plt.ylabel('Сумма продаж')
    plt.show()
    #зададим параметры оглавление, подписи по осям

# %% [markdown]
# Посчитаем корреляцию для других платформ из самых продаваемых и оценок критиков.

# %%
for item in top_sales_platform_last_year:
    title = 'Как влияют на продажи игр на ' + item + ' оценки критиков. 2008-2016'
    display(f'{title}',
    data_last_years
    .loc[data_last_years.platform == item][['critic_score', 'sum_of_sales']]
    .corr(method='spearman') #проверим корреляцию методом Спирмена для данных по другим платформам за 2008-2016 года
    )
# Out:
# 'Как влияют на продажи игр на ps3 оценки критиков. 2008-2016'
#               critic_score  sum_of_sales
# critic_score      1.000000      0.668577
# sum_of_sales      0.668577      1.000000
# 'Как влияют на продажи игр на wiiu оценки критиков. 2008-2016'
#               critic_score  sum_of_sales
# critic_score      1.000000      0.452475
# sum_of_sales      0.452475      1.000000
# 'Как влияют на продажи игр на xone оценки критиков. 2008-2016'
#               critic_score  sum_of_sales
# critic_score      1.000000      0.531578
# sum_of_sales      0.531578      1.000000

# %% [markdown]
# Построим диаграммы рассеяния для других платформ из самых продаваемых и оценок пользователей.

# %%
for item in top_sales_platform_last_year:
    title = 'Как влияют на продажи игр на ' + item + ' оценки пользователей. 2008-2016'
  
    plt.scatter(
        data_last_years.loc[data_last_years.platform == item].user_score,
        data_last_years.loc[data_last_years.platform == item].sum_of_sales
    )
    #построим диаграмму рассеяния
    
    plt.title(title)
    plt.xlabel('Оценки пользователей')
    plt.ylabel('Сумма продаж')
    plt.show()
    #зададим параметры оглавление, подписи по осям

# %% [markdown]
# Посчитаем корреляцию для других платформ из самых продаваемых и оценок пользователей.

# %%
for item in top_sales_platform_last_year:
    title = 'Как влияют на продажи игр на ' + item + ' оценки пользователей. 2008-2016'
    display(f'{title}',
    data_last_years
    .loc[data_last_years.platform == item][['user_score', 'sum_of_sales']]
    .corr(method='spearman') #проверим корреляцию методом Спирмена для данных по другим платформам за 2008-2016 года
    )
# Out:
# 'Как влияют на продажи игр на ps3 оценки пользователей. 2008-2016'
#               user_score  sum_of_sales
# user_score      1.000000      0.305133
# sum_of_sales    0.305133      1.000000
# 'Как влияют на продажи игр на wiiu оценки пользователей. 2008-2016'
#               user_score  sum_of_sales
# user_score      1.000000      0.491348
# sum_of_sales    0.491348      1.000000
# 'Как влияют на продажи игр на xone оценки пользователей. 2008-2016'
#               user_score  sum_of_sales
# user_score      1.000000     -0.100048
# sum_of_sales   -0.100048      1.000000

# %% [markdown]
# Если посмотреть на корреляции, то видно, что почти для всех платформ есть корреляция как оценок пользователей, так и оценок критиков. Корреляция в большинстве случаев не ярко выражена, но стоит обращать на это внимание.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Хорошие и логичные комментарии. Очень важно строить график корреляции между переменными, ведь может произойти такая ситуация, что расчет у нас очень сильный а на графике абсолютно другая картина.
#
# ---
#
# В том числе можно было построить матрицу корреляции между нужными нам переменными.
#
# И визуализировать её с помощью метода `heatmap` из библиотеки `seaborn`.
#
# </div>

# %% [markdown]
# ### 6. Изучим прибыльность по жанрам.

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='genre', values='sum_of_sales', aggfunc='median') 
    #отфильтруем данные, посчитаем среднее по продажам по жанрам
    .sort_values(by='sum_of_sales', ascending=False) 
    #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) 
    #построим диаграмму
)

plt.title('Продажи по жанрам за 2008-2016 года')
plt.xlabel('Жанр', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Средние продажи'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
data_last_years_genre_sales_df = (
    data_last_years 
    #возьмем датафрейм за 2008-2016 года
    .pivot_table(index=['genre', 'year_of_release'], values='sum_of_sales', aggfunc='median') 
    #отфильтруем данные и посчитаем суммарно продажи по году и платформе
    .pivot_table(index='year_of_release', values='sum_of_sales', columns='genre') 
    #развернем таблицу
    .reset_index() 
    #обнулим индексы
)

#создадим подграфики
fig, axs = plt.subplots(int((len(data_last_years_genre_sales_df.columns)-1)/3), 3,
                        sharex='row',
                        sharey=True,
                        figsize=(15, 20))

#зададим общее оглавление таблицы
fig.suptitle('Продажи по жанрам за 2008-2016 года') 

counter=0 #обнулим счетчик
    
#построим графики для всех топ-5 платформ по суммам продаж
for i, ax in enumerate(axs):
    for j in range(3):
        counter += 1 #добавляем единицу к счетчику
        axs[i][j].plot(data_last_years_genre_sales_df['year_of_release'],
                       data_last_years_genre_sales_df.iloc[:,counter], 'o-') #нарисуем графики  
        axs[i][j].grid() #добавим сетку
        axs[i][j].set_ylabel('Продажи, млн.', color='gray') #добавим подписи по оси y
        axs[i][j].xaxis.set_major_locator(ticker.FixedLocator(labels_xticks)) #добавим подписи по оси х
        axs[i][j].title.set_text(data_last_years_genre_sales_df.columns[counter]) #добавим подписи для каждого графика
        axs[i][j].set_xticklabels(labels_xticks, rotation=45) #повернем тики на 45 градусов

        
plt.subplots_adjust(hspace=0.7) #добавим промежуток между графиками
plt.show() #отобразим графики
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Тут тоже сделал разными графиками</div>

# %% [markdown]
# Если посмотреть на графики, то видно, что самыми популярными жанрами за период с 2008 по 2016 года были `shooter`, `platform`, `sports`, `fighting`.

# %% [markdown]
# ### 7. Вывод

# %% [markdown]
# Как видно из анализа средних по глобальным продажам по платформам самыми успешными платформами в 2008-2016 годах являются  `X360`, `PS3`, `WIIU` и `Xone`, но тенденцию к росту показывают только `Wii` и `PS3`. Из этого следует сделать упор на платформе `PS3`.
#
# Так же стоит учесть, что самыми популярными играми в 2016-ом году являются `shooter`, `platform`, `sports`, `fighting`. На их продажи стоит сделать упор.
#
# Если посмотреть на корреляции оценок пользователей и критиков по платформам, то видно, что почти для всех платформ есть корреляция как оценок пользователей, так и оценок критиков. Корреляция в большинстве случаев не ярко выражена, но стоит обращать на это внимание.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# <s>А если мы посмотрим на средние значения продаж, какие выводы мы сможем сделать ?
#
# Почему на средние значения ?
#
# Т.к. эта метрика более устойчива к выбросам, чем просто суммы и количественные показатели.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Если я верно все понял, то надо заменить функцию суммирования в пунктах 3.2...3.6 на медианное значение. Верно ли я понимаю, что для решения этой задачи мы берем средние продажи за актуальный период, а не просто смотрим тенденцию по графикам сумм продаж за этот период? Возможно, тогда стоит изменить и дальнейшую часть работы по оценке продаж по регионам. Там тоже считалось по суммам продаж.
#
# Поменял пункты 3.2...3.7, изменил так же общий вывод.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# В целом да, нам важен больше всего актуальный период. Но можно сравнить общую выборку и как поменялась она со временем в актуальном периоде.
#
#
# </div>

# %% [markdown]
# ## Составление портрета пользователя

# %% [markdown]
# ### 1. Портрет пользователя из региона NA.

# %%
(
    data_last_years  #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='platform', values='na_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по платформам
    .sort_values(by='na_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по платформам за 2008-2016 в регионе NA')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в NA'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='genre', values='na_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по жанрам
    .sort_values(by='na_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по жанрам за 2008-2016 года в регионе NA')
plt.xlabel('Жанр', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе NA'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='rating', values='na_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по рейтингу
    .sort_values(by='na_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи игр по рейтингу за 2008-2016 года')
plt.xlabel('Рейтинг', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе NA'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# Для региона `NA` топ-5 платформ по продажам игр распределяются следующим образом:
# 1. X360.
# 2. PS3.
# 3. WII.
# 4. DS.
# 5. PS4.
#
# Топ-5 жанров:
# 1. Action.
# 2. Shooter.
# 3. Sports.
# 4. Misc.
# 5. Role-playing.
#
# Видно, что приорететы по топ-5 жанров полностью соответствует распределению по общим продажам.
# По рейтингу большинство продаваемых игр принадлежат к рейтингу `E`, т.е. для всех категорий. На втором месте рейтинг `M`, т.е. для взрослых. Видимо, жанр `Е` самый широкий и большинство игр пытаются делать в этом жанре и он приносит больше прибыли.

# %% [markdown]
# ### 2. Портрет пользователя из региона EU.

# %%
(
    data_last_years  #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='platform', values='eu_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по платформам
    .sort_values(by='eu_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по платформам за 2008-2016 в регионе EU')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в EU'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='genre', values='eu_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по жанрам
    .sort_values(by='eu_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по жанрам за 2008-2016 года в регионе EU')
plt.xlabel('Жанр', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе EU'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='rating', values='eu_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по рейтингу
    .sort_values(by='eu_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи игр по рейтингу за 2008-2016 года')
plt.xlabel('Рейтинг', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе EU'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# Для региона `EU` топ-5 платформ по продажам игр распределяются следующим образом:
# 1. PS3.
# 2. X360.
# 3. WII.
# 4. PS4.
# 5. PC.
#
# Топ-5 жанров:
# 1. Action.
# 2. Shooter.
# 3. Sports.
# 4. Misc.
# 5. Role-playing.
#
# В данном регионе на 5-ом месте оказались игры жанра `racing`, тогда как остальные места соответствуют общему распределению по продажам по всем регионам.
# Интересно отметить, что в странах этого региона большинство продаваемых игр приходиться на рейтинг `M`, т.е. для взрослых. Возможно, в этом регионе люди, играющие в игры более старшего возраста.

# %% [markdown]
# ### 3. Портрет пользователя из региона JP.

# %%
(
    data_last_years  #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='platform', values='jp_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по платформам
    .sort_values(by='jp_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по платформам за 2008-2016 в регионе JP')
plt.xlabel('Платформа', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в JP'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='genre', values='jp_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по жанрам
    .sort_values(by='jp_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи по жанрам за 2008-2016 года в регионе JP')
plt.xlabel('Жанр', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе JP'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %%
(
    data_last_years #возьмем датафрейм за 2008-2016 года
    .pivot_table(index='rating', values='jp_sales', aggfunc='sum') #отфильтруем данные, посчитаем продажи по рейтингу
    .sort_values(by='jp_sales', ascending=False) #отсортируем данные по убыванию
    .plot(grid=True, kind='bar', sharex=False, figsize=(12,5)) #построим диаграмму
)

plt.title('Продажи игр по рейтингу за 2008-2016 года')
plt.xlabel('Рейтинг', color='gray')
plt.ylabel('Продажи', color='gray')
plt.legend(['Продажи в регионе JP'])
plt.show()
#зададим параметры оглавление, подписи по осям, легенда

# %% [markdown]
# Для региона `JP` топ-5 платформ по продажам игр распределяются следующим образом:
# 1. DS.
# 2. 3DS.
# 3. PS3.
# 4. PSP.
# 5. WII.
#
# Топ-5 жанров:
# 1. Role-playing.
# 2. Action.
# 3. Misc.
# 4. Sports.
# 5. Adventure.
#
# В регионе `JP` набор платформ и жанров из топ-5 сильно отличается от всех остальных регионов и с общим распределением. Видимо, это связано с культурными особенностями этого региона. Видимо, на территории данного региона находится множество производтств различных платформ и они тут более широко представлены.
# В части рейтинга так же наибольшую популярность имеют рейтинг широкой категории `Е`, а на втором месте уже рейтинг `T`, т.е. для подростков.

# %% [markdown]
# ### 4. Вывод

# %% [markdown]
# В регионе `NA` самыми продаваемые игры выходят на платформах `X360`, `PS3` и `WII`. Самыми продаваемыми играми являются `action`, `shooter` и `sports`. Большинство игр относится к жанру `E`, т.е. для всех. Видимо, это связано с ограничениями по жестокости в этом регионе и все производители стремятся выпускать игры именно в этом жанре.
#
# В регионе `EU` больше предпочитают платформу `PS3`, а на втором месте располагается платформа `X360`. Далее распределение по платформам идентичное с регионом `NA`. Жанры распределяются идентично региону `NA`. А вот рейтинг в этом регионе лидирует `M`, т.е. для взрослых. Возможно, это связано с тем, что игроки в этом регионе более старшего возраста или тут другие нормы по допустимой жестокости в играх.
#
# В регионе `JP` предпочитаемые платформы и жанры из топ-5 отличается от всех остальных регионов и с общим распределением. Так же тут явно преобладают иные платформы (`DS`, `3DS`, `PS3` и т.д.), которые не распространены в регионах `EU` и `NA`. Видимо, на территории данного региона находится множество производтств различных платформ и они тут более широко представлены. Однако, можно обратить так же внимание, что в данном регионе так же широко представлены игры на платформе `PS2`, которая уже устарела. Выбор жанров (`role-playing`, `action`, `misc` и т.д.) скорее всего связан с культурными особенностями людей, проживающих в данном регионе. Стоит провести анализ отдельно для этого вопроса. В части рейтинга так же наибольшую популярность имеют рейтинг широкой категории `Е`, а на втором месте уже рейтинг `T`, т.е. для подростков. Возможно, тут возрст играющих ниже, чем в регионе `EU`. В основном, вывод по региону `JP` можно сделать такой, что в данном регионе требуется отдельный подход к продажам с учетом культурных особенностей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Достаточно детально проанализировали наши данные и изучили портреты пользователей.
#
#
#
# Давай теперь проверим наши гипотезы.
#
# </div>

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### 1. Проверим гипотезу, что средние пользовательские рейтинги у платформ Xbox One и PC одинаковые.

# %% [markdown]
# Сформулируем гипотезы:
#
# H0: средние пользовательские рейтинги у платформ `Xbox One` и `PC` равны \
# H1: средние пользовательские рейтинги у платформ `Xbox One` и `PC` неравны.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Гипотезы сформулированы верно.
#
#
# **Best practices:**
#
# Перед проверкой гипотезы рекомендую проверить дисперсии выборок, чтобы корректно определить атрибут `equal_val` в Т–тесте.
#
#
# Так мы покажем логичность и последовательность наших действий.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Провел F-тест ниже. Верно ли я его выполнил? В моем случаи данные не распределены нормально и я провел тест Манна-Уитни, для которого</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати это еще более менее то распределение, которое можно считать нормальным. В бизнесе, достаточно редко можно встретить прям "идеальное" нормальное распределение. Поэтому, здесь мы могли вовсе обойтись стандартным Т-тестом.
#
# Сам F-тест сделан корректно.
#
# </div>

# %% [markdown]
# Создадим 2 переменные и запишем туда срезы данных из датафрейма для платформ Xbox One и для PC для данных за 2008-2016 года.

# %%
data_xb_last_years = data_last_years.loc[(data_last_years.platform == 'xone') &
                                         (data_last_years.user_score.isna() == False)] 
#запишем в новую переменную данные по платформе Xbox One и откинем значения NaN в столбце user_score
data_pc_last_years = data_last_years.loc[(data_last_years.platform == 'pc') &
                                         (data_last_years.user_score.isna() == False)]
#запишем в новую переменную данные по платформе PC и откинем значения NaN в столбце user_score

# %% [markdown]
# Проверим, что дисперсии равны. Для этого проведем F-тест методом CDF.
#
# Гипотезы:
#
# H0: дисперсии двух выборок равны \
# H1: дисперсии двух выборок неравны.

# %%
dfn = len(data_xb_last_years.user_score) - 1 #посчитаем количество степеней свободы для первой выборки
dfd = len(data_pc_last_years.user_score) - 1 #посчитаем количество степеней свободы для первой выборки

stat = np.var(data_xb_last_years.user_score, ddof=1)/np.var(data_pc_last_years.user_score, ddof=1) #посчитаем статистику

p = st.stats.f.cdf(stat, dfn, dfd) #проведем F-тест

print(f'stat={stat:.3f}, p={p:.3f}') #выведем значение статистики и p-value
if p > 0.05: #создадим условие, что при значении p-value больше статистической значимости в 5% не отклоняем H0 и если меньше, то отклоняем H0 и принимаем H1
    print('Нет досточных оснований, чтобы отклонить H0')
else:
    print('Есть достаточно оснований, чтобы отклонить H0, принимаем H1.')
# Out:
# stat=0.807, p=0.044
# Есть достаточно оснований, чтобы отклонить H0, принимаем H1.

# %% [markdown]
# F-тест показал, что дисперсии выборок не равны.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# <s>Если код не помещается в одну строку, рекомендую переносить его на следующую подстроку если мы внутри одного метода пишем код или с помощью обратного слеша, если применяем несколько методов. Так код читается быстрее и понятнее.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Сделал покомпактнее</div>

# %% [markdown]
# Проверим нормально ли распределены данные в этих двух переменных по столбцу `user_score` с помощью Q-Q plot.
# Для этого напишем функцию для отрисовка графика в числах Z-шкалы.

# %%
def qq_plot(x, title): #создадим функцию для отрисовка графика qq-plot
    m = x.mean() #высчитаем медиану в выборке
    std = x.std() #высчитаем выборочное стандартное отклонение
    x = (x - m)/std #переведем данные в Z-шкалу

    sm.qqplot(x, line ='45') #создадим график Q-Q plot
    plt.title(title)
    plt.show()

# %%
qq_plot(data_xb_last_years.user_score, 'График Q-Q plot для пользовательской оценки платформы Xbox One. 2008-2016') 
#построим график для данных из столбца user_score среза данных по платформе Xbox One

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный и классный график для оценки распределения данных 👍
#
# </div>

# %%
qq_plot(data_pc_last_years.user_score, 'График Q-Q plot для пользовательской оценки платформы PC. 2008-2016')
#построим график для данных из столбца user_score среза данных по платформе PC

# %% [markdown]
# Так как данные в наших выборках не распределены нормально и нет возможности применить тест Стьюдента, то применим U-тест Манни-Уитни для сравнения двух средних.

# %%
stat, p = st.stats.mannwhitneyu(data_xb_last_years.user_score, data_pc_last_years.user_score) 
#применим тест Манни-Уитни

print(f'stat={stat:.3f}, p={p:.3f}') 
#выведем значение статистики и p-value

if p > 0.05: 
#создадим условие, что при значении p-value больше статистической значимости в 5% 
#не отклоняем H0 и если меньше, то отклоняем H0 и принимаем H1

    print('Нет досточных оснований, чтобы отклонить H0')
else:
    print('Есть достаточно оснований, чтобы отклонить H0, принимаем H1.')
# Out:
# stat=41275.000, p=0.017
# Есть достаточно оснований, чтобы отклонить H0, принимаем H1.

# %% [markdown]
# С помощью теста мы можем откинуть H0 и приминаем гипотезу H1 о том, что среднии двух выборок неравны.

# %% [markdown]
# ### 2. Проверим гипотезу, что средние пользовательские рейтинги у жанров Action и Sports разные.

# %% [markdown]
# Сформулируем гипотезы:
#
# H0: средние пользовательские рейтинги у жанров `Action` и `Sports` равны \
# H1: средние пользовательские рейтинги у жанров `Action` и `Sports` неравны.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Гипотезы сформулированы верно.
#
#
#
# </div>

# %% [markdown]
# Создадим 2 переменные и запишем туда срезы данных из датафрейма для жанров Action и Sports за 2008-2016 года.

# %%
data_action_last_years = data_last_years.loc[(data_last_years.genre == 'action') & (data_last_years.user_score.isna() == False)]
#запишем в новую переменную данные по жанру action и откинем значения NaN в столбце user_score
data_sports_last_years = data_last_years.loc[(data_last_years.genre == 'sports') & (data_last_years.user_score.isna() == False)]
#запишем в новую переменную данные по жанру sports и откинем значения NaN в столбце user_score

# %% [markdown]
# Проверим, что дисперсии равны. Для этого проведем F-тест методом CDF.
#
# Гипотезы:
#
# H0: дисперсии двух выборок равны \
# H1: дисперсии двух выборок неравны.

# %%
dfn = len(data_action_last_years.user_score) - 1 #посчитаем количество степеней свободы для первой выборки
dfd = len(data_sports_last_years.user_score) - 1 #посчитаем количество степеней свободы для первой выборки

stat = np.var(data_action_last_years.user_score, ddof=1)/np.var(data_sports_last_years.user_score, ddof=1)
#посчитаем статистику

p = st.stats.f.cdf(stat, dfn, dfd) #проведем F-тест

print(f'stat={stat:.3f}, p={p:.3f}') #выведем значение статистики и p-value
if p > 0.05:
#создадим условие, что при значении p-value больше статистической значимости в 5%
#не отклоняем H0 и если меньше, то отклоняем H0 и принимаем H1
    print('Нет досточных оснований, чтобы отклонить H0')
else:
    print('Есть достаточно оснований, чтобы отклонить H0, принимаем H1.')
# Out:
# stat=0.615, p=0.000
# Есть достаточно оснований, чтобы отклонить H0, принимаем H1.

# %% [markdown]
# F-тест показал, что дисперсии выборок не равны.

# %% [markdown]
# Проверим нормально ли распределены данные в этих двух переменных по столбцу `user_score` с помощью Q-Q plot.

# %%
qq_plot(data_action_last_years.user_score, 'График Q-Q plot для пользовательской оценки жанра Action. 2008-2016') #построим график для данных из столбца user_score среза данных по жанру Action

# %%
qq_plot(data_sports_last_years.user_score, 'График Q-Q plot для пользовательской оценки жанра Sports. 2008-2016') #построим график для данных из столбца user_score среза данных по жанру Sports

# %% [markdown]
# Так как данные в наших выборках не распределены нормально и нет возможности применить тест Стьюдента, то применим U-тест Манни-Уитни для сравнения двух средних.

# %%
stat, p = st.stats.mannwhitneyu(data_action_last_years.user_score, data_sports_last_years.user_score) #применим тест Манни-Уитни
print(f'stat={stat:.3f}, p={p:.3f}') #выведем значение статистики и p-value
if p > 0.05: #создадим условие, что при значении p-value больше статистической значимости в 5% не отклоняем H0 и если меньше, то отклоняем H0 и принимаем H1
    print('Нет досточных оснований, чтобы отклонить H0')
else:
    print('Есть достаточно оснований, чтобы отклонить H0, принимаем H1.')
# Out:
# stat=328150.500, p=0.000
# Есть достаточно оснований, чтобы отклонить H0, принимаем H1.

# %% [markdown]
# Тест показал, что можем отклонить H0 и принимаем H1, т.е. среднии двух выборок неравны. Странно, что p-value имеет значение 0.

# %% [markdown]
# ### 3. Вывод

# %% [markdown]
# Из приведенных гипотез о равенстве средних ни одна не подтвердилась. В первой части мы проверяли равенство средних значений в выборках по платформам `Xbox One` и `PC`, а во второй равенство средних по выборкам в жанрах `Action` и `Sports`.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Обрати внимание, что наши действия также повторяются с точки зрения расчетов статистических тестов, это говорит о том, что мы можем также создать здесь функцию 😊
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Данный проект выполнен для оценки компании "Стримчик" на 2017 год.
#
# При знакомстве с исходными данными были определены основные проблемы в виде многочисленных пропущенных данных, неверные названия столбцов и неверный тип данных. Для устранения этих проблем была проведена предобработка данных. Так же в датафрейм был добавлен новый столбец с суммарными продажами по играм по всем регионам.
#
# Как видно из анализа средних по глобальным продажам по платформам самыми успешными платформами в 2008-2016 годах являются  `X360`, `PS3`, `WIIU` и `Xone`, но тенденцию к росту показывают только `Wii` и `PS3`. Из этого следует сделать упор на платформе `PS3`.
#
# Так же стоит учесть, что самыми популярными играми в 2008-2016 годах являются `shooter`, `platform`, `sports`, `fighting`. На их продажи стоит сделать упор.
#
# Если посмотреть на корреляции оценок пользователей и критиков по платформам, то видно, что почти для всех платформ есть корреляция как оценок пользователей, так и оценок критиков. Корреляция в большинстве случаев не ярко выражена, но стоит обращать на это внимание.
#
# В части распределения по регионам можно сделать следующие выводы.
# - В регионе `NA` самыми продаваемые игры выходят на платформах `X360`, `PS3` и `WII`. Самыми продаваемыми играми являются `action`, `shooter` и `sports`. Большинство игр относится к жанру `E`, т.е. для всех. Видимо, это связано с ограничениями по жестокости в этом регионе и все производители стремятся выпускать игры именно в этом жанре.
# - В регионе `EU` больше предпочитают платформу `PS3`, а на втором месте располагается платформа `X360`. Далее распределение по платформам идентичное с регионом `NA`. Жанры распределяются идентично региону `NA`. А вот рейтинг в этом регионе лидирует `M`, т.е. для взрослых. Возможно, это связано с тем, что игроки в этом регионе более старшего возраста или тут другие нормы по допустимой жестокости в играх.
# - В регионе `JP` предпочитаемые платформы и жанры из топ-5 отличается от всех остальных регионов и с общим распределением. Так же тут явно преобладают иные платформы (`DS`, `3DS`, `PS3` и т.д.), которые не распространены в регионах `EU` и `NA`. Видимо, на территории данного региона находится множество производтств различных платформ и они тут более широко представлены. Однако, можно обратить так же внимание, что в данном регионе так же широко представлены игры на платформе `PS2`, которая уже устарела. Выбор жанров (`role-playing`, `action`, `misc` и т.д.) скорее всего связан с культурными особенностями людей, проживающих в данном регионе. Стоит провести анализ отдельно для этого вопроса. В части рейтинга так же наибольшую популярность имеют рейтинг широкой категории `Е`, а на втором месте уже рейтинг `T`, т.е. для подростков. Возможно, тут возрст играющих ниже, чем в регионе `EU`. В основном, вывод по региону `JP` можно сделать такой, что в данном регионе требуется отдельный подход к продажам с учетом культурных особенностей.
#
# В первой части проверки гипотез мы проверяли равенство средних значений в выборках по платформам `Xbox One` и `PC`, а во второй равенство средних по выборкам в жанрах `Action` и `Sports`. Из приведенных гипотез о равенстве средних ни одна не подтвердилась. Это говорит о том, что данные жанры и платформы имеют разную популярность, что можно увидеть из графиков по продажам.
#
# В дальнейшим, рекомендую сделать больший упор на собираемости данных по рейтингам как от критиков так и от пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
#
# **[общий комментарий]** Ячейки **markdown** в том числе мы можем использовать как дополнительный способ стилизации нашего проекта. Оставил ниже ссылку, с примерами стилизации.
#
# https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента: </b>
#
# Спасибо, изучу)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
#
# Возвращаю проект обратно, чтобы убедиться что все мои комментарии понятны.
#
# Если вдруг у тебя возникнут какие-то вопросы, то я с радостью отвечу на них 😊
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Рад, что в целом все понятно и особенно здорово, что сразу стараешься применить новые знания на практике, ведь так они усвоятся гораздо быстрее. Тогда предлагаю двигаться дальше.
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊
#
# ---
#
#
# Мои контакты для связи:
#
# ТГ: https://t.me/Evgeniy_Dd
#
# Почта: daschenko.e@gmail.com
#
#
# </div>
